# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/conda-forge/miniforge/releases/download/23.11.0-0/Mambaforge-23.11.0-0-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:16
# 🔁 Restarting kernel...

# %%
# !mamba install -c conda-forge rdkit
# Out:
# Looking for: ['rdkit']
#
# [+] 0.0s
# [+] 0.1s
# conda-forge/linux-64   1%
# conda-forge/noarch    ⣾  [+] 0.2s
# conda-forge/linux-64   5%
# conda-forge/noarch    20%[+] 0.3s
# conda-forge/linux-64  13%
# conda-forge/noarch    40%[+] 0.4s
# conda-forge/linux-64  22%
# conda-forge/noarch    50%[+] 0.5s
# conda-forge/linux-64  27%
# conda-forge/noarch    60%[+] 0.6s
# conda-forge/linux-64  31%
# conda-forge/noarch    70%[+] 0.7s
# conda-forge/linux-64  35%
# conda-forge/noarch    80%[+] 0.8s
# conda-forge/linux-64  40%
# conda-forge/noarch    90%conda-forge/noarch
# [+] 0.9s
# conda-forge/linux-64  48%[+] 1.0s
# conda-forge/linux-64  57%[+] 1.1s
# conda-forge/linux-64  62%[+] 1.2s
# conda-forge/linux-64  70%[+] 1.3s
# conda-forge/linux-64  75%[+] 1.4s
# conda-forge/linux-64  79%[+] 1.5s
# conda-forge/linux-64  88%conda-forge/linux-64
#
# Pinned packages:
#   - python 3.10.*
#   - python 3.10.*
#   - python_abi 3.10.* *cp310*
#   - cuda-version 12.*
#
#
# Transaction
#
#   Prefix: /usr/local
#
#   Updating specs:
#
#    - rdkit
#    - ca-certificates
#    - certifi
#    - openssl
#
#
#   Package                         Version  Build                Channel           Size
# ────────────────────────────────────────────────────────────────────────────────────────
#   Install:
# ────────────────────────────────────────────────────────────────────────────────────────
#
#   + zlib                           1.2.13  hd590300_5           conda-forge       93kB
#   + xorg-libice                     1.1.1  hd590300_0           conda-forge       58kB
#   + xorg-xextproto                  7.3.0  h0b41bf4_1003        conda-forge       30kB
#   + libpng                         1.6.43  h2797004_0           conda-forge      288kB
#   + libboost                       1.84.0  h8013b2b_2           conda-forge        3MB
#   + libjpeg-turbo                   3.0.0  hd590300_1           conda-forge      619kB
#   + lerc                            4.0.0  h27087fc_0           conda-forge      282kB
#   + libdeflate                       1.20  hd590300_0           conda-forge       72kB
#   + libwebp-base                    1.4.0  hd590300_0           conda-forge      439kB
#   + kiwisolver                      1.4.5  py310hd41b1e2_1      conda-forge       73kB
#   + qhull                          2020.2  h434a139_5           conda-forge      553kB
#   + xorg-libxau                    1.0.11  hd590300_0           conda-forge       14kB
#   + libbrotlicommon                 1.1.0  hd590300_1           conda-forge       69kB
#   + unicodedata2                   15.1.0  py310h2372a71_0      conda-forge      374kB
#   + libexpat                        2.6.2  h59595ed_0           conda-forge       74kB
#   + pcre2                           10.43  hcad00b1_0           conda-forge      951kB
#   + pixman                         0.43.2  h59595ed_0           conda-forge      387kB
#   + greenlet                        3.0.3  py310hc6cd4ac_0      conda-forge      211kB
#   + chardet                         5.2.0  py310hff52083_2      conda-forge      243kB
#   + libgfortran5                   13.2.0  h3d2ce59_13          conda-forge        1MB
#   + xorg-renderproto               0.11.1  h7f98852_1002        conda-forge       10kB
#   + xorg-kbproto                    1.0.7  h7f98852_1002        conda-forge       27kB
#   + xorg-xproto                    7.0.31  h7f98852_1007        conda-forge       75kB
#   + pthread-stubs                     0.4  h36c2ea0_1001        conda-forge        6kB
#   + xorg-libxdmcp                   1.1.3  h7f98852_0           conda-forge       19kB
#   + xorg-libsm                      1.2.4  h7391055_0           conda-forge       27kB
#   + freetype                       2.12.1  h267a509_2           conda-forge      635kB
#   + libtiff                         4.6.0  h1dd3fc0_3           conda-forge      283kB
#   + libbrotlienc                    1.1.0  hd590300_1           conda-forge      283kB
#   + libbrotlidec                    1.1.0  hd590300_1           conda-forge       33kB
#   + expat                           2.6.2  h59595ed_0           conda-forge      138kB
#   + libglib                        2.80.2  hf974151_0           conda-forge        4MB
#   + libgfortran-ng                 13.2.0  h69a702a_13          conda-forge       48kB
#   + libxcb                           1.15  h0b41bf4_0           conda-forge      384kB
#   + libpq                            16.3  ha72fbe1_0           conda-forge        3MB
#   + openjpeg                        2.5.2  h488ebb8_0           conda-forge      342kB
#   + lcms2                            2.16  hb7c19ff_0           conda-forge      245kB
#   + brotli-bin                      1.1.0  hd590300_1           conda-forge       19kB
#   + fontconfig                     2.14.2  h14ed4e7_0           conda-forge      272kB
#   + libopenblas                    0.3.27  pthreads_hac2b453_1  conda-forge        6MB
#   + xorg-libx11                     1.8.9  h8ee46fc_0           conda-forge      828kB
#   + pillow                         10.3.0  py310hf73ecf8_0      conda-forge       42MB
#   + brotli                          1.1.0  hd590300_1           conda-forge       19kB
#   + libblas                         3.9.0  23_linux64_openblas  conda-forge       15kB
#   + xorg-libxext                    1.3.4  h0b41bf4_2           conda-forge       50kB
#   + xorg-libxrender                0.9.11  hd590300_0           conda-forge       38kB
#   + libcblas                        3.9.0  23_linux64_openblas  conda-forge       15kB
#   + liblapack                       3.9.0  23_linux64_openblas  conda-forge       15kB
#   + numpy                           2.1.0  py310hf9f9071_0      conda-forge        8MB
#   + contourpy                       1.2.1  py310hd41b1e2_0      conda-forge      242kB
#   + libboost-python                1.84.0  py310ha7c98ff_5      conda-forge      122kB
#   + font-ttf-dejavu-sans-mono        2.37  hab24e00_0           conda-forge      397kB
#   + font-ttf-inconsolata            3.000  h77eed37_0           conda-forge       97kB
#   + font-ttf-source-code-pro        2.038  h77eed37_0           conda-forge      701kB
#   + font-ttf-ubuntu                  0.83  h77eed37_2           conda-forge        2MB
#   + python-tzdata                  2024.1  pyhd8ed1ab_0         conda-forge      144kB
#   + pytz                           2024.1  pyhd8ed1ab_0         conda-forge      189kB
#   + cycler                         0.12.1  pyhd8ed1ab_0         conda-forge       13kB
#   + pyparsing                       3.1.4  pyhd8ed1ab_0         conda-forge       90kB
#   + munkres                         1.1.4  pyh9f0ad1d_0         conda-forge       12kB
#   + six                            1.16.0  pyh6c4a22f_0         conda-forge       14kB
#   + typing_extensions              4.12.2  pyha770c72_0         conda-forge       40kB
#   + freetype-py                     2.3.0  pyhd8ed1ab_0         conda-forge       59kB
#   + fonts-conda-forge                   1  0                    conda-forge        4kB
#   + python-dateutil                 2.9.0  pyhd8ed1ab_0         conda-forge      223kB
#   + typing-extensions              4.12.2  hd8ed1ab_0           conda-forge       10kB
#   + fonts-conda-ecosystem               1  0                    conda-forge        4kB
#   + fonttools                      4.53.1  py310h5b4e0ec_0      conda-forge        2MB
#   + pandas                          2.2.2  py310hf9f9076_1      conda-forge       13MB
#   + sqlalchemy                     2.0.32  py310h5b4e0ec_0      conda-forge        3MB
#   + cairo                          1.18.0  h3faef2a_0           conda-forge      982kB
#   + matplotlib-base                 3.9.2  py310hf02ac8c_0      conda-forge        7MB
#   + pycairo                        1.26.1  py310he029307_0      conda-forge      116kB
#   + librdkit                    2024.03.5  h79cfef2_3           conda-forge       21MB
#   + rlpycairo                       0.2.0  pyhd8ed1ab_0         conda-forge       15kB
#   + reportlab                       4.2.2  py310hc51659f_0      conda-forge        2MB
#   + rdkit                       2024.03.5  py310h57e35d3_3      conda-forge        6MB
#
#   Upgrade:
# ────────────────────────────────────────────────────────────────────────────────────────
#
#   - ca-certificates            2023.11.17  hbcca054_0           conda-forge     Cached
#   + ca-certificates             2024.8.30  hbcca054_0           conda-forge      159kB
#   - openssl                         3.2.0  hd590300_1           conda-forge     Cached
#   + openssl                         3.3.1  hb9d3cd8_3           conda-forge        3MB
#   - certifi                    2023.11.17  pyhd8ed1ab_0         conda-forge     Cached
#   + certifi                      2024.7.4  pyhd8ed1ab_0         conda-forge      159kB
#
#   Summary:
#
#   Install: 77 packages
#   Upgrade: 3 packages
#
#   Total download: 138MB
#
# ────────────────────────────────────────────────────────────────────────────────────────
#
#
# [+] 0.0s
# Downloading        0%
# Extracting         0%[+] 0.1s
# Downloading  (5)   0%
# Extracting         0%xorg-libice                                         58.5kB @ 569.2kB/s  0.1s
# xorg-xextproto                                      30.3kB @ 250.4kB/s  0.1s
# libpng                                             288.2kB @   2.4MB/s  0.1s
# ca-certificates                                    159.0kB @   1.1MB/s  0.1s
# zlib                                                92.8kB @ 635.6kB/s  0.2s
# kiwisolver                                          73.1kB @ 501.9kB/s  0.0s
# unicodedata2                                       374.1kB @   2.3MB/s  0.0s
# libbrotlicommon                                     69.4kB @ 399.9kB/s  0.1s
# xorg-renderproto                                     9.6kB @  52.7kB/s  0.0s
# [+] 0.2s
# Downloading  (5)   1%
# Extracting   (9)  ⣾  freetype                                           635.0kB @   3.1MB/s  0.0s
# libgfortran5                                         1.5MB @   6.6MB/s  0.1s
# libbrotlidec                                        32.8kB @ 147.7kB/s  0.0s
# chardet                                            243.4kB @   1.1MB/s  0.1s
# libgfortran-ng                                      48.4kB @ 212.6kB/s  0.0s
# openjpeg                                           341.6kB @   1.3MB/s  0.1s
# lcms2                                              245.2kB @ 918.4kB/s  0.0s
# brotli-bin                                          19.0kB @  71.0kB/s  0.0s
# brotli                                              19.4kB @  70.8kB/s  0.0s
# libblas                                             14.9kB @  54.3kB/s  0.0s
# [+] 0.3s
# Downloading  (5)   4%
# Extracting  (17)  ⣾  libboost-python                                    122.3kB @ 395.1kB/s  0.0s
# munkres                                             12.5kB @  39.9kB/s  0.0s
# pyparsing                                           90.1kB @ 285.7kB/s  0.0s
# font-ttf-dejavu-sans-mono                          397.4kB @   1.2MB/s  0.1s
# certifi                                            159.3kB @ 468.5kB/s  0.1s
# python-dateutil                                    222.7kB @ 624.1kB/s  0.0s
# [+] 0.4s
# Downloading  (5)   7%
# Extracting  (21)  ⣾  cairo                                              982.4kB @   2.5MB/s  0.1s
# lerc                                               281.8kB @ 706.2kB/s  0.0s
# fonttools                                            2.4MB @   5.8MB/s  0.1s
# qhull                                              552.9kB @   1.2MB/s  0.1s
# xorg-libxau                                         14.5kB @  30.7kB/s  0.1s
# [+] 0.5s
# Downloading  (5)  13%
# Extracting  (23)  ⣾  pixman                                             386.8kB @ 753.9kB/s  0.1s
# xorg-libxdmcp                                       19.1kB @  37.3kB/s  0.0s
# pthread-stubs                                        5.6kB @  10.3kB/s  0.1s
# rdkit                                                6.4MB @  11.4MB/s  0.2s
# libbrotlienc                                       282.5kB @ 503.2kB/s  0.1s
# expat                                              137.6kB @ 241.8kB/s  0.1s
# [+] 0.6s
# Downloading  (5)  22%
# Extracting  (29)  ⣾  xorg-libxrender                                     37.8kB @  60.7kB/s  0.1s
# libcblas                                            14.8kB @  23.8kB/s  0.1s
# liblapack                                           14.8kB @  23.6kB/s  0.1s
# cycler                                              13.5kB @  19.7kB/s  0.1s
# six                                                 14.3kB @  20.7kB/s  0.1s
# typing_extensions                                   39.9kB @  57.8kB/s  0.1s
# [+] 0.7s
# Downloading  (5)  28%
# Extracting  (33)  ⣾  libopenblas                                          5.6MB @   7.9MB/s  0.2s
# pycairo                                            116.0kB @ 154.7kB/s  0.1s
# rlpycairo                                           14.9kB @  19.9kB/s  0.1s
# libdeflate                                          71.5kB @  95.1kB/s  0.0s
# librdkit                                            21.0MB @  27.9MB/s  0.4s
# [+] 0.8s
# Downloading  (5)  35%
# Extracting  (36)  ⣾  xorg-xproto                                         74.9kB @  92.0kB/s  0.1s
# xorg-kbproto                                        27.3kB @  31.9kB/s  0.1s
# openssl                                              2.9MB @   3.3MB/s  0.1s
# libpq                                                2.5MB @   2.9MB/s  0.1s
# matplotlib-base                                      6.9MB @   7.8MB/s  0.2s
# [+] 0.9s
# Downloading  (5)  41%
# Extracting  (38)  ⣾  contourpy                                          241.9kB @ 253.0kB/s  0.1s
# font-ttf-inconsolata                                96.5kB @ 100.9kB/s  0.1s
# fonts-conda-ecosystem                                3.7kB @   3.8kB/s  0.1s
# font-ttf-ubuntu                                      1.6MB @   1.6MB/s  0.1s
# font-ttf-source-code-pro                           700.8kB @ 708.1kB/s  0.1s
# [+] 1.0s
# Downloading  (5)  43%
# Extracting  (42)  ⣾  pcre2                                              950.8kB @ 934.4kB/s  0.0s
# libwebp-base                                       439.0kB @ 426.9kB/s  0.1s
# libexpat                                            73.7kB @  71.7kB/s  0.1s
# xorg-libxext                                        50.1kB @  48.6kB/s  0.0s
# freetype-py                                         58.9kB @  55.5kB/s  0.1s
# xorg-libsm                                          27.4kB @  25.1kB/s  0.1s
# [+] 1.1s
# Downloading  (5)  47%
# Extracting  (45)  ⣾  sqlalchemy                                           2.8MB @   2.5MB/s  0.1s
# fontconfig                                         272.0kB @ 239.8kB/s  0.0s
# libglib                                              3.9MB @   3.4MB/s  0.2s
# xorg-libx11                                        828.1kB @ 716.6kB/s  0.1s
# [+] 1.2s
# Downloading  (5)  51%
# Extracting  (50)  ⣾  python-tzdata                                      144.0kB @ 118.3kB/s  0.1s
# pytz                                               188.5kB @ 153.4kB/s  0.1s
# libjpeg-turbo                                      618.6kB @ 497.3kB/s  0.1s
# greenlet                                           211.0kB @ 169.1kB/s  0.1s
# [+] 1.3s
# Downloading  (5)  55%
# Extracting  (54)  ⣾  fonts-conda-forge                                    4.1kB @   3.1kB/s  0.1s
# typing-extensions                                   10.1kB @   7.8kB/s  0.1s
# [+] 1.4s
# Downloading  (5)  60%
# Extracting  (56)  ⣾  libboost                                             2.8MB @   2.0MB/s  0.2s
# libtiff                                            282.7kB @ 200.7kB/s  0.1s
# libxcb                                             384.2kB @ 271.8kB/s  0.1s
# [+] 1.5s
# Downloading  (4)  64%
# Extracting  (59)  ⣾  reportlab                                            2.4MB @   1.6MB/s  0.3s
# pandas                                              13.0MB @   8.3MB/s  0.6s
# [+] 1.6s
# Downloading  (2)  69%
# Extracting  (60)  ⣾  [+] 1.7s
# Downloading  (2)  75%
# Extracting  (61)  ⣾  numpy                                                7.8MB @   4.6MB/s  0.3s
# [+] 1.8s
# Downloading  (1)  77%
# Extracting  (62)  ⣾  [+] 1.9s
# Downloading  (1)  83%
# Extracting  (60)  ⣾  [+] 2.0s
# Downloading  (1)  90%
# Extracting  (59)  ⣾  [+] 2.1s
# Downloading  (1)  96%
# Extracting  (58)  ⣾  pillow                                              41.8MB @  19.9MB/s  0.7s
# [+] 2.2s
# Downloading      100%
# Extracting  (59)  ⣾  [+] 2.3s
# Downloading      100%
# Extracting  (58)  ⣾  [+] 2.4s
# Downloading      100%
# Extracting  (57)  ⣾  [+] 2.5s
# Downloading      100%
# Extracting  (56)  ⣾  [+] 2.6s
# Downloading      100%
# Extracting  (56)  ⣾  [+] 2.7s
# Downloading      100%
# Extracting  (56)  ⣾  [+] 2.8s
# Downloading      100%
# Extracting  (56)  ⣾  [+] 2.9s
# Downloading      100%
# Extracting  (56)  ⣾  [+] 3.0s
# Downloading      100%
# Extracting  (55)  ⣾  [+] 3.1s
# Downloading      100%
# Extracting  (55)  ⣾  [+] 3.2s
# Downloading      100%
# Extracting  (55)  ⣾  [+] 3.3s
# Downloading      100%
# Extracting  (54)  ⣾  [+] 3.4s
# Downloading      100%
# Extracting  (54)  ⣾  [+] 3.5s
# Downloading      100%
# Extracting  (54)  ⣾  [+] 3.6s
# Downloading      100%
# Extracting  (54)  ⣾  [+] 3.7s
# Downloading      100%
# Extracting  (54)  ⣾  [+] 3.8s
# Downloading      100%
# Extracting  (54)  ⣾  [+] 3.9s
# Downloading      100%
# Extracting  (53)  ⣾  [+] 4.0s
# Downloading      100%
# Extracting  (53)  ⣾  [+] 4.1s
# Downloading      100%
# Extracting  (51)  ⣾  [+] 4.2s
# Downloading      100%
# Extracting  (50)  ⣾  [+] 4.3s
# Downloading      100%
# Extracting  (49)  ⣾  [+] 4.4s
# Downloading      100%
# Extracting  (48)  ⣾  [+] 4.5s
# Downloading      100%
# Extracting  (47)  ⣾  [+] 4.6s
# Downloading      100%
# Extracting  (44)  ⣾  [+] 4.7s
# Downloading      100%
# Extracting  (43)  ⣾  [+] 4.8s
# Downloading      100%
# Extracting  (42)  ⣾  [+] 4.9s
# Downloading      100%
# Extracting  (39)  ⣾  [+] 5.0s
# Downloading      100%
# Extracting  (37)  ⣾  [+] 5.1s
# Downloading      100%
# Extracting  (36)  ⣾  [+] 5.2s
# Downloading      100%
# Extracting  (34)  ⣾  [+] 5.3s
# Downloading      100%
# Extracting  (33)  ⣾  [+] 5.4s
# Downloading      100%
# Extracting  (30)  ⣾  [+] 5.5s
# Downloading      100%
# Extracting  (28)  ⣾  [+] 5.6s
# Downloading      100%
# Extracting  (26)  ⣾  [+] 5.7s
# Downloading      100%
# Extracting  (24)  ⣾  [+] 5.8s
# Downloading      100%
# Extracting  (23)  ⣾  [+] 5.9s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 6.0s
# Downloading      100%
# Extracting  (21)  ⣾  [+] 6.1s
# Downloading      100%
# Extracting  (20)  ⣾  [+] 6.2s
# Downloading      100%
# Extracting  (17)  ⣾  [+] 6.3s
# Downloading      100%
# Extracting  (15)  ⣾  [+] 6.4s
# Downloading      100%
# Extracting  (11)  ⣾  [+] 6.5s
# Downloading      100%
# Extracting   (9)  ⣾  [+] 6.6s
# Downloading      100%
# Extracting   (8)  ⣾  [+] 6.7s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 6.8s
# Downloading      100%
# Extracting   (3)  ⣾  [+] 6.9s
# Downloading      100%
# Extracting   (2)  ⣾
# Downloading and Extracting Packages:
#
# done
# done
# done

# %%
import pandas as pd

# %%
url='https://raw.githubusercontent.com/Keshav6265/Drug-discovery/main/data/acetylcholinesterase_03_bioactivity_data_curated.csv'
df = pd.read_csv(url)
df
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL133897              CCOc1nn(-c2cccc(OCc3ccccc3)c2)c(=O)o1
# 1          CHEMBL336398         O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC1CC1
# 2          CHEMBL131588  CN(C(=O)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F)c1ccccc1
# 3          CHEMBL130628      O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F
# 4          CHEMBL130478          CSc1nc(-c2ccc(OC(F)(F)F)cc2)nn1C(=O)N(C)C
# ...                 ...                                                ...
# 6364      CHEMBL2238282              O=C(/C=C/c1ccc(N2CCCCC2)cc1)c1sccc1Cl
# 6365      CHEMBL4636881  CC(=O)Nc1c(F)cc(C(=O)N[C@H]2CC[C@H](O)CC2)cc1O...
# 6366      CHEMBL4635134          CNC(=O)c1cc(C(=O)NC2CC2)cn(Cc2ccccc2)c1=O
# 6367      CHEMBL4639128  COCc1nc2cnc3cc(-c4c(C)noc4C)c(OC[C@H]4CCNC4)cc...
# 6368      CHEMBL5078078  CC(C)(O)c1ccc(N2Cc3c(ccnc3-c3ccc(F)cc3OCC(F)(F...
#
#       standard_value         class
# 0             750.00        active
# 1             100.00        active
# 2           50000.00      inactive
# 3             300.00        active
# 4             800.00        active
# ...              ...           ...
# 6364          160.00        active
# 6365         7943.28  intermediate
# 6366       100000.00      inactive
# 6367        63095.73      inactive
# 6368        10000.00      inactive
#
# [6369 rows x 4 columns]

# %%
df_no_smiles = df.drop(columns='canonical_smiles')

# %%
smiles = []

for i in df.canonical_smiles.tolist():
  cpd = str(i).split('.')
  cpd_longest = max(cpd, key = len)
  smiles.append(cpd_longest)

smiles = pd.Series(smiles, name = 'canonical_smiles')

# %%
df_clean_smiles = pd.concat([df_no_smiles,smiles], axis=1)
df_clean_smiles
# Out:
#      molecule_chembl_id  standard_value         class  \
# 0          CHEMBL133897          750.00        active
# 1          CHEMBL336398          100.00        active
# 2          CHEMBL131588        50000.00      inactive
# 3          CHEMBL130628          300.00        active
# 4          CHEMBL130478          800.00        active
# ...                 ...             ...           ...
# 6364      CHEMBL2238282          160.00        active
# 6365      CHEMBL4636881         7943.28  intermediate
# 6366      CHEMBL4635134       100000.00      inactive
# 6367      CHEMBL4639128        63095.73      inactive
# 6368      CHEMBL5078078        10000.00      inactive
#
#                                        canonical_smiles
# 0                 CCOc1nn(-c2cccc(OCc3ccccc3)c2)c(=O)o1
# 1            O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC1CC1
# 2     CN(C(=O)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F)c1ccccc1
# 3         O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F
# 4             CSc1nc(-c2ccc(OC(F)(F)F)cc2)nn1C(=O)N(C)C
# ...                                                 ...
# 6364              O=C(/C=C/c1ccc(N2CCCCC2)cc1)c1sccc1Cl
# 6365  CC(=O)Nc1c(F)cc(C(=O)N[C@H]2CC[C@H](O)CC2)cc1O...
# 6366          CNC(=O)c1cc(C(=O)NC2CC2)cn(Cc2ccccc2)c1=O
# 6367  COCc1nc2cnc3cc(-c4c(C)noc4C)c(OC[C@H]4CCNC4)cc...
# 6368  CC(C)(O)c1ccc(N2Cc3c(ccnc3-c3ccc(F)cc3OCC(F)(F...
#
# [6369 rows x 4 columns]

# %%
import numpy as np
from rdkit import Chem
from rdkit.Chem import Descriptors, Lipinski

# %%
def lipinski(smiles, verbose=False):

    moldata= []
    for elem in smiles:
        mol=Chem.MolFromSmiles(elem)
        moldata.append(mol)

    baseData= np.arange(1,1)
    i=0
    for mol in moldata:

        desc_MolWt = Descriptors.MolWt(mol)
        desc_MolLogP = Descriptors.MolLogP(mol)
        desc_NumHDonors = Lipinski.NumHDonors(mol)
        desc_NumHAcceptors = Lipinski.NumHAcceptors(mol)

        row = np.array([desc_MolWt,
                        desc_MolLogP,
                        desc_NumHDonors,
                        desc_NumHAcceptors])

        if(i==0):
            baseData=row
        else:
            baseData=np.vstack([baseData, row])
        i=i+1

    columnNames=["MW","LogP","NumHDonors","NumHAcceptors"]
    descriptors = pd.DataFrame(data=baseData,columns=columnNames)

    return descriptors

# %%
df_lipinski = lipinski(df_clean_smiles.canonical_smiles)
df_lipinski
# Out:
#            MW     LogP  NumHDonors  NumHAcceptors
# 0     312.325  2.80320         0.0            6.0
# 1     376.913  4.55460         0.0            5.0
# 2     426.851  5.35740         0.0            5.0
# 3     404.845  4.70690         0.0            5.0
# 4     346.334  3.09530         0.0            6.0
# ...       ...      ...         ...            ...
# 6364  331.868  5.28790         0.0            3.0
# 6365  414.477  3.95740         3.0            4.0
# 6366  325.368  1.14840         2.0            4.0
# 6367  511.626  5.60034         1.0            8.0
# 6368  460.427  5.21660         1.0            4.0
#
# [6369 rows x 4 columns]

# %%
df_combined = pd.concat([df,df_lipinski], axis=1)

# %%
df_combined
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL133897              CCOc1nn(-c2cccc(OCc3ccccc3)c2)c(=O)o1
# 1          CHEMBL336398         O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC1CC1
# 2          CHEMBL131588  CN(C(=O)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F)c1ccccc1
# 3          CHEMBL130628      O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F
# 4          CHEMBL130478          CSc1nc(-c2ccc(OC(F)(F)F)cc2)nn1C(=O)N(C)C
# ...                 ...                                                ...
# 6364      CHEMBL2238282              O=C(/C=C/c1ccc(N2CCCCC2)cc1)c1sccc1Cl
# 6365      CHEMBL4636881  CC(=O)Nc1c(F)cc(C(=O)N[C@H]2CC[C@H](O)CC2)cc1O...
# 6366      CHEMBL4635134          CNC(=O)c1cc(C(=O)NC2CC2)cn(Cc2ccccc2)c1=O
# 6367      CHEMBL4639128  COCc1nc2cnc3cc(-c4c(C)noc4C)c(OC[C@H]4CCNC4)cc...
# 6368      CHEMBL5078078  CC(C)(O)c1ccc(N2Cc3c(ccnc3-c3ccc(F)cc3OCC(F)(F...
#
#       standard_value         class       MW     LogP  NumHDonors  \
# 0             750.00        active  312.325  2.80320         0.0
# 1             100.00        active  376.913  4.55460         0.0
# 2           50000.00      inactive  426.851  5.35740         0.0
# 3             300.00        active  404.845  4.70690         0.0
# 4             800.00        active  346.334  3.09530         0.0
# ...              ...           ...      ...      ...         ...
# 6364          160.00        active  331.868  5.28790         0.0
# 6365         7943.28  intermediate  414.477  3.95740         3.0
# 6366       100000.00      inactive  325.368  1.14840         2.0
# 6367        63095.73      inactive  511.626  5.60034         1.0
# 6368        10000.00      inactive  460.427  5.21660         1.0
#
#       NumHAcceptors
# 0               6.0
# 1               5.0
# 2               5.0
# 3               5.0
# 4               6.0
# ...             ...
# 6364            3.0
# 6365            4.0
# 6366            4.0
# 6367            8.0
# 6368            4.0
#
# [6369 rows x 8 columns]

# %%
def pIC50(input):
    pIC50 = []

    for i in input['standard_value_norm']:
        molar = i*(10**-9) # Converts nM to M
        pIC50.append(-np.log10(molar))

    input['pIC50'] = pIC50
    x = input.drop('standard_value_norm',axis= 1)

    return x

# %%
df_combined.standard_value.describe()
# Out:
# count    6.369000e+03
# mean     1.032539e+05
# std      9.065149e+05
# min      0.000000e+00
# 25%      1.445000e+02
# 50%      2.260000e+03
# 75%      1.580000e+04
# max      4.960000e+07
# Name: standard_value, dtype: float64

# %%
def norm_value(input):
    norm = []

    for i in input['standard_value']:
        if i > 100000000:
          i = 100000000
        norm.append(i)

    input['standard_value_norm'] = norm
    x = input.drop('standard_value',axis=1)

    return x

# %%
df_norm = norm_value(df_combined)
df_norm
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL133897              CCOc1nn(-c2cccc(OCc3ccccc3)c2)c(=O)o1
# 1          CHEMBL336398         O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC1CC1
# 2          CHEMBL131588  CN(C(=O)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F)c1ccccc1
# 3          CHEMBL130628      O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F
# 4          CHEMBL130478          CSc1nc(-c2ccc(OC(F)(F)F)cc2)nn1C(=O)N(C)C
# ...                 ...                                                ...
# 6364      CHEMBL2238282              O=C(/C=C/c1ccc(N2CCCCC2)cc1)c1sccc1Cl
# 6365      CHEMBL4636881  CC(=O)Nc1c(F)cc(C(=O)N[C@H]2CC[C@H](O)CC2)cc1O...
# 6366      CHEMBL4635134          CNC(=O)c1cc(C(=O)NC2CC2)cn(Cc2ccccc2)c1=O
# 6367      CHEMBL4639128  COCc1nc2cnc3cc(-c4c(C)noc4C)c(OC[C@H]4CCNC4)cc...
# 6368      CHEMBL5078078  CC(C)(O)c1ccc(N2Cc3c(ccnc3-c3ccc(F)cc3OCC(F)(F...
#
#              class       MW     LogP  NumHDonors  NumHAcceptors  \
# 0           active  312.325  2.80320         0.0            6.0
# 1           active  376.913  4.55460         0.0            5.0
# 2         inactive  426.851  5.35740         0.0            5.0
# 3           active  404.845  4.70690         0.0            5.0
# 4           active  346.334  3.09530         0.0            6.0
# ...            ...      ...      ...         ...            ...
# 6364        active  331.868  5.28790         0.0            3.0
# 6365  intermediate  414.477  3.95740         3.0            4.0
# 6366      inactive  325.368  1.14840         2.0            4.0
# 6367      inactive  511.626  5.60034         1.0            8.0
# 6368      inactive  460.427  5.21660         1.0            4.0
#
#       standard_value_norm
# 0                  750.00
# 1                  100.00
# 2                50000.00
# 3                  300.00
# 4                  800.00
# ...                   ...
# 6364               160.00
# 6365              7943.28
# 6366            100000.00
# 6367             63095.73
# 6368             10000.00
#
# [6369 rows x 8 columns]

# %%
df_norm.standard_value_norm.describe()
# Out:
# count    6.369000e+03
# mean     1.032539e+05
# std      9.065149e+05
# min      0.000000e+00
# 25%      1.445000e+02
# 50%      2.260000e+03
# 75%      1.580000e+04
# max      4.960000e+07
# Name: standard_value_norm, dtype: float64

# %%
df_final = pIC50(df_norm)
df_final
# Out:
# <ipython-input-16-25c365788526>:6: RuntimeWarning: divide by zero encountered in log10
#   pIC50.append(-np.log10(molar))
# /usr/local/lib/python3.10/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL133897              CCOc1nn(-c2cccc(OCc3ccccc3)c2)c(=O)o1
# 1          CHEMBL336398         O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC1CC1
# 2          CHEMBL131588  CN(C(=O)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F)c1ccccc1
# 3          CHEMBL130628      O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F
# 4          CHEMBL130478          CSc1nc(-c2ccc(OC(F)(F)F)cc2)nn1C(=O)N(C)C
# ...                 ...                                                ...
# 6364      CHEMBL2238282              O=C(/C=C/c1ccc(N2CCCCC2)cc1)c1sccc1Cl
# 6365      CHEMBL4636881  CC(=O)Nc1c(F)cc(C(=O)N[C@H]2CC[C@H](O)CC2)cc1O...
# 6366      CHEMBL4635134          CNC(=O)c1cc(C(=O)NC2CC2)cn(Cc2ccccc2)c1=O
# 6367      CHEMBL4639128  COCc1nc2cnc3cc(-c4c(C)noc4C)c(OC[C@H]4CCNC4)cc...
# 6368      CHEMBL5078078  CC(C)(O)c1ccc(N2Cc3c(ccnc3-c3ccc(F)cc3OCC(F)(F...
#
#              class       MW     LogP  NumHDonors  NumHAcceptors     pIC50
# 0           active  312.325  2.80320         0.0            6.0  6.124939
# 1           active  376.913  4.55460         0.0            5.0  7.000000
# 2         inactive  426.851  5.35740         0.0            5.0  4.301030
# 3           active  404.845  4.70690         0.0            5.0  6.522879
# 4           active  346.334  3.09530         0.0            6.0  6.096910
# ...            ...      ...      ...         ...            ...       ...
# 6364        active  331.868  5.28790         0.0            3.0  6.795880
# 6365  intermediate  414.477  3.95740         3.0            4.0  5.100000
# 6366      inactive  325.368  1.14840         2.0            4.0  4.000000
# 6367      inactive  511.626  5.60034         1.0            8.0  4.200000
# 6368      inactive  460.427  5.21660         1.0            4.0  5.000000
#
# [6369 rows x 8 columns]

# %%
df_final.pIC50.describe()
# Out:
# count    6369.000000
# mean             inf
# std              NaN
# min         1.304518
# 25%         4.801343
# 50%         5.645892
# 75%         6.840132
# max              inf
# Name: pIC50, dtype: float64

# %%
df_final.to_csv('acetylcholinesterase_04_bioactivity_data_3class_pIC50.csv')

# %%
df_2class = df_final[df_final['class'] != 'intermediate']
df_2class
# Out:
# /usr/local/lib/python3.10/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL133897              CCOc1nn(-c2cccc(OCc3ccccc3)c2)c(=O)o1
# 1          CHEMBL336398         O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC1CC1
# 2          CHEMBL131588  CN(C(=O)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F)c1ccccc1
# 3          CHEMBL130628      O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F
# 4          CHEMBL130478          CSc1nc(-c2ccc(OC(F)(F)F)cc2)nn1C(=O)N(C)C
# ...                 ...                                                ...
# 6363      CHEMBL2238280             Cc1ccc(C(=O)/C=C/c2ccc(N3CCCCC3)cc2)s1
# 6364      CHEMBL2238282              O=C(/C=C/c1ccc(N2CCCCC2)cc1)c1sccc1Cl
# 6366      CHEMBL4635134          CNC(=O)c1cc(C(=O)NC2CC2)cn(Cc2ccccc2)c1=O
# 6367      CHEMBL4639128  COCc1nc2cnc3cc(-c4c(C)noc4C)c(OC[C@H]4CCNC4)cc...
# 6368      CHEMBL5078078  CC(C)(O)c1ccc(N2Cc3c(ccnc3-c3ccc(F)cc3OCC(F)(F...
#
#          class       MW     LogP  NumHDonors  NumHAcceptors     pIC50
# 0       active  312.325  2.80320         0.0            6.0  6.124939
# 1       active  376.913  4.55460         0.0            5.0  7.000000
# 2     inactive  426.851  5.35740         0.0            5.0  4.301030
# 3       active  404.845  4.70690         0.0            5.0  6.522879
# 4       active  346.334  3.09530         0.0            6.0  6.096910
# ...        ...      ...      ...         ...            ...       ...
# 6363    active  311.450  4.94292         0.0            3.0  6.886057
# 6364    active  331.868  5.28790         0.0            3.0  6.795880
# 6366  inactive  325.368  1.14840         2.0            4.0  4.000000
# 6367  inactive  511.626  5.60034         1.0            8.0  4.200000
# 6368  inactive  460.427  5.21660         1.0            4.0  5.000000
#
# [4751 rows x 8 columns]

# %%
df_2class.to_csv('acetylcholinesterase_05_bioactivity_data_2class_pIC50.csv')

# %%
import seaborn as sns
sns.set(style='ticks')
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(5.5, 5.5))

sns.countplot(x='class', data=df_2class, edgecolor='black')

plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('Frequency', fontsize=14, fontweight='bold')

plt.savefig('plot_bioactivity_class.pdf')

# %%
df_2class = df_2class[~np.isinf(df_2class[['MW', 'LogP', 'pIC50']].to_numpy()).any(axis=1)]

# %%
# Plot again
plt.figure(figsize=(8, 8))
sns.scatterplot(x='MW', y='LogP', data=df_2class, hue='class', size='pIC50', edgecolor='black', alpha=0.7)
plt.xlabel('MW', fontsize=14, fontweight='bold')
plt.ylabel('LogP', fontsize=14, fontweight='bold')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0)
plt.savefig('plot_MW_vs_LogP.png')

# %%
plt.figure(figsize=(5.5, 5.5))

sns.boxplot(x = 'class', y = 'pIC50', data = df_2class)

plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('pIC50 value', fontsize=14, fontweight='bold')

plt.savefig('plot_ic50.pdf')
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)

# %%
def mannwhitney(descriptor, verbose=False):
  # https://machinelearningmastery.com/nonparametric-statistical-significance-tests-in-python/
  from numpy.random import seed
  from numpy.random import randn
  from scipy.stats import mannwhitneyu

# seed the random number generator
  seed(1)

# actives and inactives
  selection = [descriptor, 'class']
  df = df_2class[selection]
  active = df[df['class'] == 'active']
  active = active[descriptor]

  selection = [descriptor, 'class']
  df = df_2class[selection]
  inactive = df[df['class'] == 'inactive']
  inactive = inactive[descriptor]

# compare samples
  stat, p = mannwhitneyu(active, inactive)
  #print('Statistics=%.3f, p=%.3f' % (stat, p))

# interpret
  alpha = 0.05
  if p > alpha:
    interpretation = 'Same distribution (fail to reject H0)'
  else:
    interpretation = 'Different distribution (reject H0)'

  results = pd.DataFrame({'Descriptor':descriptor,
                          'Statistics':stat,
                          'p':p,
                          'alpha':alpha,
                          'Interpretation':interpretation}, index=[0])
  filename = 'mannwhitneyu_' + descriptor + '.csv'
  results.to_csv(filename)

  return results

# %%
mannwhitney('pIC50')
# Out:
#   Descriptor  Statistics    p  alpha                      Interpretation
# 0      pIC50   5533041.0  0.0   0.05  Different distribution (reject H0)

# %%
plt.figure(figsize=(5.5, 5.5))

sns.boxplot(x = 'class', y = 'MW', data = df_2class)

plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('MW', fontsize=14, fontweight='bold')

plt.savefig('plot_MW.pdf')
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)

# %%
mannwhitney('MW')
# Out:
#   Descriptor  Statistics             p  alpha  \
# 0         MW   3581416.0  6.836462e-68   0.05
#
#                        Interpretation
# 0  Different distribution (reject H0)

# %%
plt.figure(figsize=(5.5, 5.5))

sns.boxplot(x = 'class', y = 'LogP', data = df_2class)

plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('LogP', fontsize=14, fontweight='bold')

plt.savefig('plot_LogP.pdf')
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)

# %%
mannwhitney('LogP')
# Out:
#   Descriptor  Statistics             p  alpha  \
# 0       LogP   3704729.5  2.212268e-89   0.05
#
#                        Interpretation
# 0  Different distribution (reject H0)

# %%
plt.figure(figsize=(5.5, 5.5))

sns.boxplot(x = 'class', y = 'NumHDonors', data = df_2class)

plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('NumHDonors', fontsize=14, fontweight='bold')

plt.savefig('plot_NumHDonors.pdf')
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)

# %%
mannwhitney('NumHDonors')
# Out:
#    Descriptor  Statistics             p  alpha  \
# 0  NumHDonors   3131739.5  2.570274e-16   0.05
#
#                        Interpretation
# 0  Different distribution (reject H0)

# %%
plt.figure(figsize=(5.5, 5.5))

sns.boxplot(x = 'class', y = 'NumHAcceptors', data = df_2class)

plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('NumHAcceptors', fontsize=14, fontweight='bold')

plt.savefig('plot_NumHAcceptors.pdf')
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)

# %%
mannwhitney('NumHAcceptors')
# Out:
#       Descriptor  Statistics         p  alpha  \
# 0  NumHAcceptors   2979061.0  0.000004   0.05
#
#                        Interpretation
# 0  Different distribution (reject H0)

# %%
! zip -r results.zip . -i *.csv *.pdf
# Out:
#   adding: plot_MW_vs_LogP.pdf (deflated 10%)
#   adding: acetylcholinesterase_05_bioactivity_data_2class_pIC50.csv (deflated 75%)
#   adding: mannwhitneyu_NumHAcceptors.csv (deflated 11%)
#   adding: mannwhitneyu_pIC50.csv (deflated 9%)
#   adding: mannwhitneyu_LogP.csv (deflated 9%)
#   adding: plot_NumHDonors.pdf (deflated 38%)
#   adding: mannwhitneyu_MW.csv (deflated 9%)
#   adding: plot_NumHAcceptors.pdf (deflated 39%)
#   adding: plot_ic50.pdf (deflated 35%)
#   adding: acetylcholinesterase_04_bioactivity_data_3class_pIC50.csv (deflated 76%)
#   adding: plot_LogP.pdf (deflated 37%)
#   adding: mannwhitneyu_NumHDonors.csv (deflated 11%)
#   adding: plot_bioactivity_class.pdf (deflated 39%)
#   adding: plot_MW.pdf (deflated 38%)
